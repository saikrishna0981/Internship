# %% [markdown]
# ## Day 6
# ## Date - 29-May-2019

# %% [markdown]
# ## Problem 1
# Draw a pie plot based on number of wins for each team

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas
wins=[]
df=pandas.read_csv('DataFiles/Match.csv')
df1=pandas.read_csv('DataFiles/Match.csv',usecols=['Season_Year'])
years=np.unique(df1.values)
df2=pandas.read_csv('DataFiles/Match.csv',usecols=['Team1'])
teams=np.unique(df2.values)
for i in range(0,len(teams)):
    a=0
    for j in range(0,len(df1.values)):
        if teams[i]==df.iat[j,10]:
            a=a+1
    wins.append(a)
labels=teams
sizes=wins
plt.pie(sizes,labels=labels,autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
class hI():
    sizes=[]
    df=pd.read_csv('DataFiles/Match.csv')
    teams=np.unique(df.Team1)
    def wins(x,df):
        count=0
        for i in range(len(df)):
            if x == df.match_winner[i]:
                count=count+1
        return count
    for x in teams:
        ans=wins(x,df)
        sizes.append(ans)
    plt.pie(sizes,labels=teams,autopct='%1.1f%%',startangle=90)
    plt.show()
pie_plot=hI

# %% [markdown]
# ## Problem 2
# Draw a bar graph for number of matches won (i,e.consider win if the team wins both the toss and match)  for the team “Mumbai Indians” for all years

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
class Bar():
    def __init__(self,team):
        def matcheswon(x,team,df):
            count=0
            for i in range(len(df)):
                if (x==df.Season_Year[i]) and team==df.match_winner[i] and team==df.Toss_Winner[i]:
                    count=count+1
            return count
        df=pd.read_csv('DataFiles/Match.csv')
        years=np.unique(df.Season_Year)
        x=[]
        for z in years:
            ans=matcheswon(z,team,df)
            x.append(ans)
        width=1/3
        plt.bar(years,x,width,color='green')
bar=Bar('Mumbai Indians')
